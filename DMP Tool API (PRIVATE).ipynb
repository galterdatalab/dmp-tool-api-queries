# %% [markdown]
# # Authorize yourself and get an access token
#
# `curl -v https://dmptool.orgoauth/token -X POST -H "Accept: application/json" -d "grant_type=client_credentials&client_id=395007db55a95eeac8e97299185&client_secret=266cb658d0cc6e4a9ca4209b09d0f8"`
#
# ## Example Output
#
# `...{"access_token":"smzETo2MwuscqDsW-I8joB0bLuV_qf1W3SqzC2yPA1o","token_type":"Bearer","expires_in":7200,"scope":"public read_dmps","created_at":1714684830}`
#
#
#
# # Example `curl` commands to retrieve plans
# `curl -v https://dmptool.org/api/v2/plans -H "Accept: application/json" -H "Authorization: Bearer x8DpXhDMmdkLWZVTPvY4pSADNUBIYRgSixjGztq08no"`
#
# `curl -v https://dmptool.org/api/v2/plans/89799 -H "Accept: application/json" -H "Authorization: Bearer x8DpXhDMmdkLWZVTPvY4pSADNUBIYRgSixjGztq08no"`
#
# `curl -v https://dmptool.org/api/v2/plans/126595 -H "Accept: application/json" -H "Authorization: Bearer x8DpXhDMmdkLWZVTPvY4pSADNUBIYRgSixjGztq08no"`
#
#
# # API Documentation
#
# https://github.com/CDLUC3/dmptool/wiki/API-Overview
#
#
# # Support Contacts
#
# - Brian Riley: Brian.Riley@ucop.edu
# - Maria Praetzellis: Maria.Praetzellis@ucop.edu

# %%
import subprocess
import re

command = ["curl -v https://dmptool.org/oauth/token -X POST -H \"Accept: application/json\" -d \"grant_type=client_credentials&client_id=395007db55a95eeac8e97299185&client_secret=266cb658d0cc6e4a9ca4209b09d0f8\""]

process = subprocess.run(command, capture_output=True, text=True, shell=True)

access_token = ''

if process.returncode == 0:
    print("Command executed successfully:")
    match = re.search(r'"access_token"\s*:\s*"([^"]+)"', process.stdout)

    if match:
        access_token = match.group(1)
        print("Access Token: ", access_token)
else:
    print("Command failed with error:")
    print(process.stderr)
# Out:
# Command executed successfully:
# Access Token:  HB_SHxrDsDjaQpBhydoypJPp_WNlafYNIQQvfsFPn-E

# %%
import requests
import json

# API URL
base_url = 'https://dmptool.org/api/v2'

# Specify the endpoint you want to access, e.g., 'plans', 'templates'
endpoint = '/plans/126595'

# Leave blank to query all plans
# To search for individual plans, use '/12345' (e.g., '/126595')
one_plan = ''

api_url = f'{base_url}{endpoint}{one_plan}'

# access_token generated with call above
headers = {'Authorization': 'Bearer ' + access_token} 

try:
    response = requests.get(api_url, headers=headers)
    response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)
    
    # Assuming the response is in JSON format
    data = response.json()
    print(json.dumps(data, indent=2))

except requests.exceptions.RequestException as e:
    print(f"Request failed: {e}")
except json.JSONDecodeError:
    print("Failed to decode JSON response")
except Exception as e:
    print(f"An unexpected error occurred: {e}")


###
##
# When querying one plan at a time, you can extract data as so...
##
###


# Print title
#print (data['items'][0]['dmp']['title'])

# Description
#print (data['items'][0]['dmp']['description'])

# DMP ID
#print (data['items'][0]['dmp']['dmp_id']['identifier'])

# Contributors (just the first one)
#print (data['items'][0]['dmp']['contributor'][0]['name'])

# Project information. Title and description are also here
#print (data['items'][0]['dmp']['project'][0])

# Project details like funder
#print (data['items'][0]['dmp']['project'][0]['funding'][0]['name'])

# Project funding opportunity URL
#print (data['items'][0]['dmp']['project'][0]['funding'][0]['grant_id']['identifier'])

# Project details like funding status
#print (data['items'][0]['dmp']['project'][0]['funding'][0]['funding_status'])

# What DMP template was used?
#print (data['items'][0]['dmp']['dmproadmap_template']['title'])

# Project expected dataset
print (data['items'][0]['dmp']['dataset'][0]['type'])
print (data['items'][0]['dmp']['dataset'][0]['title'])
print (data['items'][0]['dmp']['dataset'][0]['description'])
print (data['items'][0]['dmp']['dataset'][0]['keyword'])
# Out:
# {
#   "application": "DMP Tool",
#   "api_version": 2,
#   "source": "GET /api/v2/plans/126595",
#   "time": "2025-02-27T21:41:07Z",
#   "caller": "matthew.carson@northwestern.edu",
#   "code": 200,
#   "message": "OK",
#   "page": 1,
#   "per_page": 100,
#   "total_items": 1,
#   "items": [
#     {
#       "dmp": {
#         "title": "Repurposing rapamycin for direct modulation of renal endothelial cells to mitigate ischemia-reperfusion injury",
#         "description": "<p>Ischemia-reperfusion injury (IRI) is a leading cause of acute kidney injury (AKI) and significantly affects patient outcomes in kidney transplantation and critical care. With over 72,864 end-stage kidney disease patients awaiting transplants, kidneys are highly susceptible to IRI due to unavoidable ischemic periods during procurement and transplantation. This often results in delayed graft function (DGF) in 21.3% of U.S. kidney transplant recipients, necessitating dialysis within seven days post-transplant and adversely impacting patient outcomes. Additionally, AKI affects up to 50\u201360% of intensive care unit patients, exacerbating the challenges in managing kidney injury in critical care settings. Currently, there are no effective therapies to mitigate IRI, highlighting an urgent need for effective strategies. Renal endothelial cells (ECs), among the first affected by IRI, trigger inflammatory cascades that exacerbate renal injury. Because of their central role in this process, directly targeting ECs holds significant therapeutic potential. One promising approach involves the use of rapamycin, an mTOR inhibitor with known immunosuppressive properties. However, its widespread distribution and off-target effects limit its efficacy.</p> <p>Building on our previous work with poly(ethylene glycol)-b-poly(propylene sulfide) (PEG-b-PPS) polymersomes (PS) to induce anti-inflammatory phenotypes in monocyte lineage cells, we propose to repurpose rapamycin for targeted delivery to renal ECs. During the K99 training phase, we will develop rapamycin-loaded PS (rPS) and functionalize them with fucoidan using a rapid, simple tannic acid (TA)-FeIII coating technique in aqueous conditions, designed to target the overexpression of P-selectin on activated renal ECs during IRI. In Aim 1, we will demonstrate that fucoidan decorated TA-FeIII rPS (FrPS) achieves predominant uptake by renal ECs. In Aim 2, we will investigate the therapeutic impact of ex vivo pretreated renal grafts with FrPS in mitigating IRI during kidney transplantation. In the R00 independent phase, we aim to translate these findings into a systemic therapy for AKI. We will develop a systemic rapamycin formulation to target renal ECs through fucoidan coated TA-FeIII Kolliphor\u00ae HS 15 (Fsol, an inactive ingredient listed in the FDA database that dissolves rapamycin powder directly without requiring organic solvents), which will produce nanoparticles less than 20\u202fnm for intravenous administration. In Aim 3, we will develop and characterize the systemic Fsol formulation. In Aim 4, we will evaluate the efficacy of P-selectin targeting Fsol in a murine bilateral renal IRI model.</p> <p>This K99/R00 research introduces a novel, targeted therapeutic strategy to mitigate IRI by inducing anti-inflammatory phenotypes in renal ECs, potentially improving outcomes for kidney transplant and AKI patients. Successful completion will provide comprehensive insights into renal EC immunobiology and support my transition to an independent investigator focused on developing innovative treatments for kidney diseases.</p>",
#         "language": "eng",
#         "created": "2024-10-02T07:04:40Z",
#         "modified": "2024-10-02T18:57:04Z",
#         "ethical_issues_exist": "unknown",
#         "dmp_id": {
#           "type": "doi",
#           "identifier": "https://doi.org/10.48321/D15A6B4FC5"
#         },
#         "contact": {
#           "name": "Simseok Yuk",
#           "mbox": "simseok.yuk@northwestern.edu",
#           "dmproadmap_affiliation": {
#             "name": "Northwestern University",
#             "affiliation_id": {
#               "type": "ror",
#               "identifier": "https://ror.org/000e0be47"
#             }
#           },
#           "contact_id": {
#             "type": "orcid",
#             "identifier": "https://orcid.org/0000-0002-6610-4940"
#           }
#         },
#         "contributor": [
#           {
#             "name": "Satish Nadig",
#             "mbox": "satish.nadig@nm.org",
#             "role": [
#               "other"
#             ],
#             "dmproadmap_affiliation": {
#               "name": "Northwestern University",
#               "affiliation_id": {
#                 "type": "ror",
#                 "identifier": "https://ror.org/000e0be47"
#               }
#             },
#             "contributor_id": {
#               "type": "orcid",
#               "identifier": "https://orcid.org/0000-0001-6090-4245"
#             }
#           },
#           {
#             "name": "Simseok A. Yuk",
#             "mbox": "simseok.yuk@northwestern.edu",
#             "role": [
#               "http://credit.niso.org/contributor-roles/data-curation",
#               "http://credit.niso.org/contributor-roles/investigation",
#               "http://credit.niso.org/contributor-roles/project-administration"
#             ],
#             "dmproadmap_affiliation": {
#               "name": "Northwestern University",
#               "affiliation_id": {
#                 "type": "ror",
#                 "identifier": "https://ror.org/000e0be47"
#               }
#             },
#             "contributor_id": {
#               "type": "orcid",
#               "identifier": "https://orcid.org/0000-0002-6610-4940"
#             }
#           },
#           {
#             "name": "Jacqueline Alexis Burke",
#             "mbox": "jacqueline.burke@northwestern.edu",
#             "role": [
#               "other"
#             ],
#             "dmproadmap_affiliation": {
#               "name": "Northwestern University",
#               "affiliation_id": {
#                 "type": "ror",
#                 "identifier": "https://ror.org/000e0be47"
#               }
#             }
#           }
#         ],
#         "project": [
#           {
#             "title": "Repurposing rapamycin for direct modulation of renal endothelial cells to mitigate ischemia-reperfusion injury",
#             "description": "<p>Ischemia-reperfusion injury (IRI) is a leading cause of acute kidney injury (AKI) and significantly affects patient outcomes in kidney transplantation and critical care. With over 72,864 end-stage kidney disease patients awaiting transplants, kidneys are highly susceptible to IRI due to unavoidable ischemic periods during procurement and transplantation. This often results in delayed graft function (DGF) in 21.3% of U.S. kidney transplant recipients, necessitating dialysis within seven days post-transplant and adversely impacting patient outcomes. Additionally, AKI affects up to 50\u201360% of intensive care unit patients, exacerbating the challenges in managing kidney injury in critical care settings. Currently, there are no effective therapies to mitigate IRI, highlighting an urgent need for effective strategies. Renal endothelial cells (ECs), among the first affected by IRI, trigger inflammatory cascades that exacerbate renal injury. Because of their central role in this process, directly targeting ECs holds significant therapeutic potential. One promising approach involves the use of rapamycin, an mTOR inhibitor with known immunosuppressive properties. However, its widespread distribution and off-target effects limit its efficacy.</p> <p>Building on our previous work with poly(ethylene glycol)-b-poly(propylene sulfide) (PEG-b-PPS) polymersomes (PS) to induce anti-inflammatory phenotypes in monocyte lineage cells, we propose to repurpose rapamycin for targeted delivery to renal ECs. During the K99 training phase, we will develop rapamycin-loaded PS (rPS) and functionalize them with fucoidan using a rapid, simple tannic acid (TA)-FeIII coating technique in aqueous conditions, designed to target the overexpression of P-selectin on activated renal ECs during IRI. In Aim 1, we will demonstrate that fucoidan decorated TA-FeIII rPS (FrPS) achieves predominant uptake by renal ECs. In Aim 2, we will investigate the therapeutic impact of ex vivo pretreated renal grafts with FrPS in mitigating IRI during kidney transplantation. In the R00 independent phase, we aim to translate these findings into a systemic therapy for AKI. We will develop a systemic rapamycin formulation to target renal ECs through fucoidan coated TA-FeIII Kolliphor\u00ae HS 15 (Fsol, an inactive ingredient listed in the FDA database that dissolves rapamycin powder directly without requiring organic solvents), which will produce nanoparticles less than 20\u202fnm for intravenous administration. In Aim 3, we will develop and characterize the systemic Fsol formulation. In Aim 4, we will evaluate the efficacy of P-selectin targeting Fsol in a murine bilateral renal IRI model.</p> <p>This K99/R00 research introduces a novel, targeted therapeutic strategy to mitigate IRI by inducing anti-inflammatory phenotypes in renal ECs, potentially improving outcomes for kidney transplant and AKI patients. Successful completion will provide comprehensive insights into renal EC immunobiology and support my transition to an independent investigator focused on developing innovative treatments for kidney diseases.</p>",
#             "start": "2025-07-01T00:00:00Z",
#             "end": "2030-07-02T00:00:00Z",
#             "funding": [
#               {
#                 "name": "National Institute of Diabetes and Digestive and Kidney Diseases (niddk.nih.gov)",
#                 "funder_id": {
#                   "type": "ror",
#                   "identifier": "https://ror.org/00adh9b73"
#                 },
#                 "grant_id": {
#                   "type": "url",
#                   "identifier": "https://grants.nih.gov/grants/guide/pa-files/PA-24-194.html"
#                 },
#                 "funding_status": "planned",
#                 "dmproadmap_funding_opportunity_id": {
#                   "type": "other",
#                   "identifier": "PA-24-194"
#                 },
#                 "dmproadmap_funded_affiliations": [
#                   {
#                     "name": "Northwestern University",
#                     "affiliation_id": {
#                       "type": "ror",
#                       "identifier": "https://ror.org/000e0be47"
#                     }
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "dataset": [
#           {
#             "type": "dataset",
#             "title": "Generic dataset",
#             "description": "No individual datasets have been defined for this DMP.",
#             "keyword": [
#               "Medical and Health Sciences",
#               "3 - Medical and Health Sciences"
#             ]
#           }
#         ],
#         "dmproadmap_template": {
#           "id": "1936",
#           "title": "Digital Curation Centre"
#         },
#         "dmproadmap_featured": "0",
#         "dmproadmap_external_system_identifier": "https://doi.org/10.48321/D15A6B4FC5",
#         "dmproadmap_privacy": "private",
#         "dmproadmap_links": {
#           "get": "https://https/api/v2/plans/126595"
#         }
#       }
#     }
#   ]
# }
# dataset
# Generic dataset
# No individual datasets have been defined for this DMP.
# ['Medical and Health Sciences', '3 - Medical and Health Sciences']
# Digital Curation Centre
